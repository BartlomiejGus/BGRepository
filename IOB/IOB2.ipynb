# %% [markdown]
# Dab czy sosna? Projekt IOB, Wykonali: Piotr Wyrzyk, Bartłomiej Guś, dla oryginalnych zdjęć

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

#Dostanie sie do drive z zdjeciami
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#Okreslenie podzialu na zbiory uczacy, walidujacy i testowy

ilosc_zbior_uczacy = 0.7
ilosc_zbior_walidujacy = 0.15
ilosc_zbior_testowy = 0.15

# %%
#Zliczanie zdjec debu
path_dab = "/content/drive/MyDrive/Colab Notebooks/dab2/"

lista_zdjec_dab = os.listdir(path_dab)
print("Liczba zdjec debu:", len(lista_zdjec_dab))
liczba_zdjec_debow = len(lista_zdjec_dab)
# Out:
# Liczba zdjec debu: 89

# %%
#Dodawanie zdjec do odpowiednich zbiorow uczacego, walidujacego i testowego dla debu

dab_zbior_uczacy = []

#Dodanie do zbioru_uczacego dab

liczba_zdjec_debow_w_zbiorze_uczacym = 0

for aktualny_plik_uczacy in lista_zdjec_dab:

  path_aktualnie_dodawane_zdjecie = path_dab + aktualny_plik_uczacy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  dab_zbior_uczacy.append(data.copy())

  liczba_zdjec_debow_w_zbiorze_uczacym += 1

  if liczba_zdjec_debow_w_zbiorze_uczacym >= ilosc_zbior_uczacy*liczba_zdjec_debow:
    break

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

dab_zbior_uczacy = np.asarray(dab_zbior_uczacy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(dab_zbior_uczacy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_12_31_286364.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_13_47_303786.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_15_03_401795.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_15_07_028580.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_15_54_340774.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_16_30_031146.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_17_10_721332.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_20_10_802479.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_21_56_320197.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_35_09_978501.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_46_50_320822.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_49_55_807978.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_50_17_625805.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_51_05_333230.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_52_06_173773.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_54_54_005599.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_02_54_514357.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_13_55_19_799569.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_04_16_613453.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_06_39_230859.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_08_38_404430.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_10_59_617142.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_12_04_172306.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_12_45_147610.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_12_58_195667.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_13_41_443383.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_17_32_938332.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_17_35_876244.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_25_01_760052.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_25_24_065660.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_25_52_955672.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_26_11_644320.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_29_37_530250.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_27_44_538549.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_30_33_649204.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_33_40_615958.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_35_57_706089.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_14_35_48_378140.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_40_17_970327.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_40_23_243200.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_40_40_807547.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_40_29_461517.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_40_52_350485.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_41_18_732683.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_41_58_203577.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_43_02_966575.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_43_08_652386.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_43_28_410154.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_44_15_135104.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_44_50_134117.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_45_32_643186.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_45_35_053154.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_45_42_397141.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_45_52_693119.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_46_04_622652.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_46_04_762770.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_47_04_535690.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_47_10_780710.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_16_57_28_861989.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_11_27_383786.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_11_48_816285.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_12_34_323091.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_12_44_577877.jpg

# %%
#Dodanie do zbioru walidującego dab

dab_zbior_walidujacy = []

index_ostatniego_pliku_dodanego = lista_zdjec_dab.index(aktualny_plik_uczacy)

liczba_zdjec_debow_w_zbiorze_walidujacym = 0

for aktualny_plik_walidujacy in lista_zdjec_dab[index_ostatniego_pliku_dodanego+1:len(lista_zdjec_dab)]:

  path_aktualnie_dodawane_zdjecie = path_dab + aktualny_plik_walidujacy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  dab_zbior_walidujacy.append(data.copy())

  liczba_zdjec_debow_w_zbiorze_walidujacym += 1

  if liczba_zdjec_debow_w_zbiorze_walidujacym >= ilosc_zbior_walidujacy*liczba_zdjec_debow:
    break

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

dab_zbior_walidujacy = np.asarray(dab_zbior_walidujacy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(dab_zbior_walidujacy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_13_08_300092.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_01_18_13_17_970142.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_02_14_38_31_492852.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_02_14_39_01_432495.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_02_14_39_26_932245.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_13_54_12_411070.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_35_910650.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_37_380766.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_45_820949.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_39_428966.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_46_655060.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_48_207261.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_13_55_44_664818.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_38_056699.jpg

# %%
#Dodanie do zbioru testowego dab:

dab_zbior_testowy = []

index_ostatniego_pliku_dodanego = lista_zdjec_dab.index(aktualny_plik_walidujacy)

liczba_zdjec_debow_w_zbiorze_testowym = 0

for aktualny_plik_testowy in lista_zdjec_dab[index_ostatniego_pliku_dodanego+1:len(lista_zdjec_dab)]:

  path_aktualnie_dodawane_zdjecie = path_dab + aktualny_plik_testowy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  dab_zbior_testowy.append(data.copy())

  liczba_zdjec_debow_w_zbiorze_testowym += 1

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

dab_zbior_testowy = np.asarray(dab_zbior_testowy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(dab_zbior_testowy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_44_994620.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_51_43_084566.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_53_01_974269.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_52_59_064324.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_52_57_846565.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_53_05_774342.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_07_14_13_39_26_897756.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_52_30_961926.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_53_03_709130.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_07_14_13_39_30_674043.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_06_09_17_53_00_082369.jpg
# /content/drive/MyDrive/Colab Notebooks/dab2/2019_07_14_13_39_19_277890.jpg

# %%
# Faktyczny podzial dab

print("Liczba zdjec w zbiorze uczacym:", liczba_zdjec_debow_w_zbiorze_uczacym)
print("Liczba zdjec w zbiorze walidujacym:", liczba_zdjec_debow_w_zbiorze_walidujacym)
print("Liczba zdjec w zbiorze testowym:", liczba_zdjec_debow_w_zbiorze_testowym)
print("W sumie zdjec:", liczba_zdjec_debow_w_zbiorze_uczacym + liczba_zdjec_debow_w_zbiorze_walidujacym + liczba_zdjec_debow_w_zbiorze_testowym)
print("Jaki procent w zbiorze uczacym:", liczba_zdjec_debow_w_zbiorze_uczacym/liczba_zdjec_debow*100)
print("Jaki procent w zbiorze walidujacym:", liczba_zdjec_debow_w_zbiorze_walidujacym/liczba_zdjec_debow*100)
print("Jaki procent w zbiorze testowym:", liczba_zdjec_debow_w_zbiorze_testowym/liczba_zdjec_debow*100)
# Out:
# Liczba zdjec w zbiorze uczacym: 63
# Liczba zdjec w zbiorze walidujacym: 14
# Liczba zdjec w zbiorze testowym: 12
# W sumie zdjec: 89
# Jaki procent w zbiorze uczacym: 70.78651685393258
# Jaki procent w zbiorze walidujacym: 15.730337078651685
# Jaki procent w zbiorze testowym: 13.48314606741573

# %%
#Zliczanie zdjec sosna
path_sosna = "/content/drive/MyDrive/Colab Notebooks/sosna2/"

lista_zdjec_sosna = os.listdir(path_sosna)
print("Liczba zdjec sosny:", len(lista_zdjec_sosna))
liczba_zdjec_sosny = len(lista_zdjec_sosna)
# Out:
# Liczba zdjec sosny: 110

# %%
#Dodawanie zdjec do odpowiednich zbiorow uczacego, walidujacego i testowego dla sosny

sosna_zbior_uczacy = []

#Dodanie do zbioru_uczacego sosna

liczba_zdjec_sosny_w_zbiorze_uczacym = 0

for aktualny_plik_uczacy in lista_zdjec_sosna:

  path_aktualnie_dodawane_zdjecie = path_sosna + aktualny_plik_uczacy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  sosna_zbior_uczacy.append(data.copy())

  liczba_zdjec_sosny_w_zbiorze_uczacym += 1

  if liczba_zdjec_sosny_w_zbiorze_uczacym >= ilosc_zbior_uczacy*liczba_zdjec_sosny:
    break

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

sosna_zbior_uczacy = np.asarray(sosna_zbior_uczacy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(sosna_zbior_uczacy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_11_05_281821.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_12_16_636796.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_15_16_709667.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_18_10_270571.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_20_05_798399.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_41_48_789286.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_44_59_181700.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_45_04_958498.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_47_00_711346.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_48_03_209217.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_48_37_659932.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_49_18_794448.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_51_47_083408.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_13_55_48_923662.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_03_00_028695.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_06_34_503400.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_11_35_367346.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_14_22_585062.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_14_49_319339.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_15_04_391192.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_15_20_689510.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_15_26_737007.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_16_13_547180.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_23_22_447772.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_25_55_500436.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_26_43_734753.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_27_37_381448.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_28_23_791837.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_30_38_121443.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_30_51_413931.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_14_33_42_024779.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_40_14_270946.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_40_33_729109.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_40_52_882298.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_41_05_008801.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_41_12_030515.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_41_56_517642.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_42_40_259611.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_47_38_427164.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_48_33_543966.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_48_34_751220.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_48_36_705478.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_50_46_371425.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_50_49_032027.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_51_57_117649.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_50_50_447217.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_52_56_772106.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_53_13_290061.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_53_59_952867.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_16_55_01_502861.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_11_18_888805.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_12_00_515222.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_22_965110.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_28_229100.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_34_423542.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_41_413911.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_44_718489.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_48_496102.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_13_54_688465.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_14_03_819383.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_14_28_558732.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_14_29_926712.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_14_40_835538.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_01_18_14_56_988386.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_02_14_40_01_648682.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_02_14_41_18_002028.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_42_024606.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_36_551767.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_43_700665.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_44_003682.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_46_907542.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_39_674406.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_13_52_59_926258.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_57_606147.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_50_104895.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_55_030294.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_57_404466.jpg

# %%
#Dodanie do zbioru walidującego sosna

sosna_zbior_walidujacy = []

index_ostatniego_pliku_dodanego = lista_zdjec_sosna.index(aktualny_plik_uczacy)

liczba_zdjec_sosny_w_zbiorze_walidujacym = 0

for aktualny_plik_walidujacy in lista_zdjec_sosna[index_ostatniego_pliku_dodanego+1:len(lista_zdjec_sosna)]:

  path_aktualnie_dodawane_zdjecie = path_sosna + aktualny_plik_walidujacy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  sosna_zbior_walidujacy.append(data.copy())

  liczba_zdjec_sosny_w_zbiorze_walidujacym += 1

  if liczba_zdjec_sosny_w_zbiorze_walidujacym >= ilosc_zbior_walidujacy*liczba_zdjec_sosny:
    break

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

sosna_zbior_walidujacy = np.asarray(sosna_zbior_walidujacy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(sosna_zbior_walidujacy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_51_397705.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_57_080328.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_55_983711.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_53_126217.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_48_400957.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_54_623879.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_52_869702.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_52_114050.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_54_332948.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_50_238510.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_49_930144.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_01_671809.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_45_758931.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_00_602077.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_48_272154.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_02_395465.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_02_405628.jpg

# %%
#Dodanie do zbioru testowego sosna

sosna_zbior_testowy = []

index_ostatniego_pliku_dodanego = lista_zdjec_sosna.index(aktualny_plik_walidujacy)

liczba_zdjec_sosny_w_zbiorze_testowym = 0

for aktualny_plik_testowy in lista_zdjec_sosna[index_ostatniego_pliku_dodanego+1:len(lista_zdjec_sosna)]:

  path_aktualnie_dodawane_zdjecie = path_sosna + aktualny_plik_testowy
  print(path_aktualnie_dodawane_zdjecie)
  data = plt.imread(path_aktualnie_dodawane_zdjecie)
  sosna_zbior_testowy.append(data.copy())

  liczba_zdjec_sosny_w_zbiorze_testowym += 1

# print("Ostatni dodany folder:", aktualny_folder_uczacy)
# print("Ostatni dodane zdjecie:",aktualny_plik_uczacy_2)
# print("Liczba dodanych zdjec do zbioru uczacego:", liczba_zdjec_debow_w_zbiorze_uczacym)

sosna_zbior_testowy = np.asarray(dab_zbior_testowy)

#Wyswietlenie przykladowego zdjecia:
plt.imshow(sosna_zbior_testowy[0])
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_00_108316.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_03_112317.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_58_964158.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_51_59_469752.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_55_434006.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_59_350356.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_53_022915.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_56_040877.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_53_03_524655.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_54_235723.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_53_16_276075.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_50_463089.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_51_532711.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_58_160844.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_52_499646.jpg
# /content/drive/MyDrive/Colab Notebooks/sosna2/2019_06_09_17_52_53_299847.jpg

# %%
# Faktyczny podzial sosna

print("Liczba zdjec w zbiorze uczacym:", liczba_zdjec_sosny_w_zbiorze_uczacym)
print("Liczba zdjec w zbiorze walidujacym:", liczba_zdjec_sosny_w_zbiorze_walidujacym)
print("Liczba zdjec w zbiorze testowym:", liczba_zdjec_sosny_w_zbiorze_testowym)
print("W sumie zdjec:", liczba_zdjec_sosny_w_zbiorze_uczacym + liczba_zdjec_sosny_w_zbiorze_walidujacym + liczba_zdjec_sosny_w_zbiorze_testowym)
print("Jaki procent w zbiorze uczacym:", liczba_zdjec_sosny_w_zbiorze_uczacym/liczba_zdjec_sosny*100)
print("Jaki procent w zbiorze walidujacym:", liczba_zdjec_sosny_w_zbiorze_walidujacym/liczba_zdjec_sosny*100)
print("Jaki procent w zbiorze testowym:", liczba_zdjec_sosny_w_zbiorze_testowym/liczba_zdjec_sosny*100)
# Out:
# Liczba zdjec w zbiorze uczacym: 77
# Liczba zdjec w zbiorze walidujacym: 17
# Liczba zdjec w zbiorze testowym: 16
# W sumie zdjec: 110
# Jaki procent w zbiorze uczacym: 70.0
# Jaki procent w zbiorze walidujacym: 15.454545454545453
# Jaki procent w zbiorze testowym: 14.545454545454545

# %%
#Przygotowanie do nauki modelu

import tensorflow as tf

y_dab_uczacy = [0 for i in range (dab_zbior_uczacy.shape[0])]
y_dab_walidujacy = [0 for i in range (dab_zbior_walidujacy.shape[0])]
y_dab_testowy = [0 for i in range (dab_zbior_testowy.shape[0])]

y_sosna_uczacy = [1 for i in range (sosna_zbior_uczacy.shape[0])]
y_sosna_walidujacy = [1 for i in range (sosna_zbior_walidujacy.shape[0])]
y_sosna_testowy = [1 for i in range (sosna_zbior_testowy.shape[0])]

zbior_uczacy = [dab_zbior_uczacy,sosna_zbior_uczacy]
zbior_uczacy = [item for podlista in zbior_uczacy for item in podlista]
zbior_uczacy = np.asarray(zbior_uczacy)

y_zbior_uczacy = [y_dab_uczacy,y_sosna_uczacy]
y_zbior_uczacy = [item for podlista in y_zbior_uczacy for item in podlista]

zbior_walidujacy = [dab_zbior_walidujacy,sosna_zbior_walidujacy]
zbior_walidujacy = [item for podlista in zbior_walidujacy for item in podlista]
zbior_walidujacy = np.asarray(zbior_walidujacy)

y_zbior_walidujacy = [y_dab_walidujacy,y_sosna_walidujacy]
y_zbior_walidujacy = [item for podlista in y_zbior_walidujacy for item in podlista]

zbior_testowy = [dab_zbior_testowy,sosna_zbior_testowy]
zbior_testowy = [item for podlista in zbior_testowy for item in podlista]
zbior_testowy = np.asarray(zbior_testowy)

y_zbior_testowy = [y_dab_testowy,y_sosna_testowy]
y_zbior_testowy = [item for podlista in y_zbior_testowy for item in podlista]


#Zamiana na kategorie
y_zbior_uczacy_one_hot = tf.keras.utils.to_categorical(y_zbior_uczacy, 2)
y_zbior_walidujacy_one_hot = tf.keras.utils.to_categorical(y_zbior_walidujacy, 2)
y_zbior_testowy_one_hot = tf.keras.utils.to_categorical(y_zbior_testowy, 2)

#Sprawdzenie
print("Wartość zbioru y_zbior_uczacy_one_hot[0]",y_zbior_uczacy_one_hot[0])

#Przeskalowanie do zakresu <0,1>
zbior_uczacy = zbior_uczacy/255
zbior_walidujacy = zbior_walidujacy/255
zbior_testowy = zbior_testowy/255

#Sprawdzenie
print("Wartość zbioru zbior_uczacy[0]",zbior_uczacy[0])
# Out:
# Wartość zbioru y_zbior_uczacy_one_hot[0] [1. 0.]
# Wartość zbioru zbior_uczacy[0] [[[0.16078431 0.2        0.16470588]
#   [0.12941176 0.16862745 0.1372549 ]
#   [0.16862745 0.20392157 0.19215686]
#   ...
#   [0.52941176 0.62745098 0.60392157]
#   [0.60392157 0.70588235 0.67058824]
#   [0.81568627 0.91764706 0.88235294]]
#
#  [[0.14901961 0.18823529 0.15294118]
#   [0.14117647 0.18039216 0.14901961]
#   [0.16862745 0.20392157 0.19215686]
#   ...
#   [0.57647059 0.67843137 0.64313725]
#   [0.63921569 0.74117647 0.69803922]
#   [0.81568627 0.91764706 0.8745098 ]]
#
#  [[0.16078431 0.2        0.15686275]
#   [0.15294118 0.19215686 0.15686275]
#   [0.16862745 0.20392157 0.18431373]
#   ...
#   [0.49803922 0.60784314 0.56078431]
#   [0.44705882 0.55686275 0.50196078]
#   [0.50588235 0.61568627 0.55686275]]
#
#  ...
#
#  [[0.29019608 0.29803922 0.34509804]
#   [0.35294118 0.36078431 0.40784314]
#   [0.45490196 0.4627451  0.50980392]
#   ...
#   [0.50196078 0.45882353 0.45098039]
#   [0.4627451  0.41960784 0.41176471]
#   [0.38823529 0.33333333 0.32941176]]
#
#  [[0.35686275 0.36470588 0.41176471]
#   [0.26666667 0.2745098  0.32156863]
#   [0.35294118 0.36078431 0.40784314]
#   ...
#   [0.53333333 0.49019608 0.4745098 ]
#   [0.48235294 0.43921569 0.42352941]
#   [0.4627451  0.40784314 0.39607843]]
#
#  [[0.38039216 0.38823529 0.43529412]
#   [0.3372549  0.34509804 0.39215686]
#   [0.36078431 0.37647059 0.41960784]
#   ...
#   [0.55294118 0.51764706 0.49019608]
#   [0.51764706 0.4745098  0.45098039]
#   [0.50196078 0.45098039 0.42745098]]]

# %%
from IPython.display import clear_output

co_ile_epok_mam_odswiezac = 3

#Rysunki w trakcie nauki
class Rysunki_w_trakcie_nauki(tf.keras.callbacks.Callback):
    
    def on_train_begin(self, logs={}):
        self.losses = []
        self.acc = []
        self.losses_val = []
        self.acc_val = []
    
    # Ta funkcja wykonuje się tylko na końcu
    def on_epoch_end(self, epoch, logs={}):

        loss = logs.get('loss')
        accuracy = logs.get('accuracy')
        loss_val = logs.get('val_loss')
        accuracy_val = logs.get('val_accuracy')

          
        # self.logs.append(logs)
        self.losses.append(loss)
        self.acc.append(accuracy)
        self.losses_val.append(loss_val)
        self.acc_val.append(accuracy_val)
        
        if epoch > 0 and epoch%co_ile_epok_mam_odswiezac==0:

            clear_output(wait=True)
            N = np.arange(0, len(self.losses))

            plt.style.use("seaborn")
            
            fig, ax = plt.subplots(2,2, figsize=(20,8))
            ax[0,0].plot(N, self.losses)
            ax[0,0].set_title("Loss - zbiór uczący")
            ax[0,0].set_ylabel("Loss")

            ax[0,1].plot(N, self.acc)
            ax[0,1].set_title("Accuracy - zbiór uczący")
            ax[0,1].set_ylabel("Accuracy")

            ax[1,0].plot(N, self.losses_val)
            ax[1,0].set_title("Loss - zbiór walidujący")
            ax[1,0].set_ylabel("Loss")

            ax[1,1].plot(N, self.acc_val)
            ax[1,1].set_title("Accuracy - zbiór walidujący")
            ax[1,1].set_ylabel("Accuracy")

            
            plt.show()

# %%
# Stworzenie modelu, architektura LeNet-5
# import visualkeras

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(6, kernel_size=(5, 5), activation='relu', padding='same', input_shape=(1024, 768, 3)))

model.add(tf.keras.layers.AveragePooling2D((2, 2), strides=(2, 2))) # w oryginale average pooling

model.add(tf.keras.layers.Conv2D(16, kernel_size=(5, 5), activation='relu', padding='valid'))
model.add(tf.keras.layers.AveragePooling2D((2, 2), strides=(2, 2)))

model.add(tf.keras.layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(50, activation='relu'))

model.add(tf.keras.layers.Dense(2, activation='softmax'))

model.compile(optimizer = "Adamax", loss = "binary_crossentropy", metrics = ["accuracy"])

# visualkeras.layered_view(model,legend = True)

# %%
# Wyswietlenie podsumowania

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1024, 768, 6)      456
#
#  average_pooling2d (AverageP  (None, 512, 384, 6)      0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 508, 380, 16)      2416
#
#  average_pooling2d_1 (Averag  (None, 254, 190, 16)     0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 250, 186, 120)     48120
#
#  flatten (Flatten)           (None, 5580000)           0
#
#  dense (Dense)               (None, 50)                279000050
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 279,051,144
# Trainable params: 279,051,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
rysunki_online = Rysunki_w_trakcie_nauki()

# Nauka modelu

model.fit(x = zbior_uczacy, y = y_zbior_uczacy_one_hot, epochs = 10, batch_size = 20, validation_data = (zbior_walidujacy, y_zbior_walidujacy_one_hot), callbacks = [rysunki_online])
# Out:
# 7/7 [==============================] - 19s 3s/step - loss: 0.2265 - accuracy: 1.0000 - val_loss: 0.5456 - val_accuracy: 0.7419

# %%
# Z zbioru testowego

wyniki_dla_zbioru_testowego =  model.evaluate(x = zbior_testowy, y = y_zbior_testowy_one_hot)
print(wyniki_dla_zbioru_testowego)
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.8264 - accuracy: 0.5000
# [0.8264327049255371, 0.5]

# %%
# # Zapis modelu

# model.save("/content/drive/MyDrive/Colab Notebooks/Modele/model_2.h5")
